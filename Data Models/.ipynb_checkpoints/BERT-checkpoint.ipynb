# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import tensorflow as tf
import tensorflow_hub as hub
import os
from datetime import datetime
import bert
from bert import run_classifier
from bert import optimization
from bert import tokenization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-794dc5bfa76d> in <module>()
#       2 import numpy as np
#       3 from sklearn.model_selection import train_test_split
# ----> 4 import tensorflow as tf
#       5 import tensorflow_hub as hub
#       6 import os
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !conda update wrapt
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::conda-build==3.10.5=py36_0
#   - defaults/osx-64::datashape==0.5.4=py36hfb22df8_0
#   - defaults/osx-64::anaconda-client==1.6.14=py36_0
#   - defaults/osx-64::anaconda-navigator==1.9.7=py36_1
#   - defaults/osx-64::bottleneck==1.2.1=py36hbd380ad_0
#   - defaults/osx-64::_anaconda_depends==2019.03=py36_0
#   - defaults/osx-64::pytest-astropy==0.3.0=py36_0
#   - defaults/osx-64::astropy==3.0.2=py36h917ab60_1
#   - defaults/osx-64::pytest-doctestplus==0.1.3=py36_0
#   - defaults/osx-64::numba==0.38.0=py36h1702cab_0
#   - defaults/osx-64::conda==4.8.0=py36_0
#   - defaults/osx-64::matplotlib==2.2.2=py36ha7267d0_0
#   - defaults/osx-64::imageio==2.3.0=py36_0
#   - defaults/osx-64::numpydoc==0.8.0=py36_0
#   - defaults/osx-64::spyder==3.2.8=py36_0
#   - defaults/osx-64::scikit-image==0.13.1=py36h1de35cc_1
#   - defaults/osx-64::blaze==0.11.3=py36h02e7a37_0
#   - defaults/osx-64::anaconda==custom=py36_1
#   - defaults/osx-64::bokeh==0.12.16=py36_0
#   - defaults/osx-64::dask==0.17.5=py36_0
#   - defaults/osx-64::statsmodels==0.9.0=py36h917ab60_0
#   - defaults/osx-64::scikit-learn==0.19.1=py36hffbff8c_0
#   - defaults/osx-64::odo==0.5.1=py36hc1af34a_0
#   - defaults/osx-64::pandas==0.23.0=py36h1702cab_0
#   - defaults/osx-64::pywavelets==0.5.2=py36h2710a04_0
#   - defaults/osx-64::numexpr==2.6.5=py36h057f876_0
#   - defaults/osx-64::scipy==1.1.0=py36hcaad992_0
#   - defaults/osx-64::pytables==3.4.3=py36h5ca999c_2
#   - defaults/osx-64::seaborn==0.8.1=py36h595ecd9_0
#   - defaults/osx-64::anaconda-project==0.8.2=py36h9ee5d53_0
#   - defaults/osx-64::h5py==2.7.1=py36ha8ecd60_2
#   - defaults/osx-64::sphinx==1.7.4=py36_0
#   - defaults/osx-64::pytest-arraydiff==0.2=py36_0
#   - defaults/osx-64::mkl_random==1.0.1=py36h78cc56f_0
#   - defaults/osx-64::mkl_fft==1.0.1=py36h917ab60_0
#   - defaults/osx-64::numpy==1.14.3=py36h9bb19eb_1
#   - defaults/osx-64::bkcharts==0.2=py36h073222e_0
#   - defaults/osx-64::patsy==0.5.0=py36_0
# /

# %%
df = pd.read_csv('./Data/cleaned english.csv')

# %%
df
# Out:
#       Unnamed: 0         ID  \
# 0              0    C45.451
# 1              1     C47.11
# 2              2     C33.79
# 3              3    C4.1961
# 4              4    C10.153
# 5              5    C10.761
# 6              6      C25.6
# 7              7    C7.1642
# 8              8  C10.152.1
# 9              9    C45.217
# 10            10    C63.126
# 11            11     C67.24
# 12            12    C7.1601
# 13            13   C59.1096
# 14            14  C7.2097.2
# 15            15    C4.2264
# 16            16    C7.15.4
# 17            17    C10.353
# 18            18  C4.2138.1
# 19            19   C59.1085
# 20            20  C4.2120.2
# 21            21    C38.482
# 22            22    C4.1274
# 23            23     C9.159
# 24            24    C10.155
# 25            25  C4.1106.1
# 26            26    C4.1751
# 27            27  C63.205.2
# 28            28     C7.240
# 29            29  C4.2144.2
# ...          ...        ...
# 4233        4233    C7.1374
# 4234        4234     C9.317
# 4235        4235    C7.2487
# 4236        4236     C7.528
# 4237        4237    C32.119
# 4238        4238    C59.530
# 4239        4239    C4.1405
# 4240        4240     C32.19
# 4241        4241   C59.1777
# 4242        4242  C26.304.2
# 4243        4243    C10.459
# 4244        4244    C4.2040
# 4245        4245  C4.2229.1
# 4246        4246   C4.774.1
# 4247        4247  C4.1633.2
# 4248        4248    C4.1936
# 4249        4249   C59.1722
# 4250        4250      C7.25
# 4251        4251     C4.313
# 4252        4252     C59.40
# 4253        4253    C7.2331
# 4254        4254    C38.448
# 4255        4255     C7.553
# 4256        4256    C10.713
# 4257        4257    C7.1287
# 4258        4258    C10.123
# 4259        4259    C10.545
# 4260        4260    C4.1082
# 4261        4261  C33.592.4
# 4262        4262    C4.2184
#
#                                                    Text Sub-task A Sub-task B  \
# 0                                             Next part        NAG       NGEN
# 1                    Iii8mllllllm\nMdxfvb8o90lplppi0005        NAG       NGEN
# 2     🤣🤣😂😂🤣🤣🤣😂osm vedio ....keep it up...make more v...        NAG       NGEN
# 3     What the fuck was this? I respect shwetabh and...        NAG       NGEN
# 4     Concerned authorities should bring arundathi R...        NAG       NGEN
# 5     It seems like these people want to be famous n...        NAG       NGEN
# 6                         Best topic for Law Students !        NAG       NGEN
# 7     Even when kabir singh was unaware that Preeti ...        CAG       NGEN
# 8                                        She is wrong .        NAG       NGEN
# 9                                            6001733614        NAG       NGEN
# 10                                       Hindi old muvi        NAG       NGEN
# 11                                                 rait        NAG       NGEN
# 12                  Very well said dude, totally agree.        NAG       NGEN
# 13                                           👌👌👌👌👌right        NAG       NGEN
# 14    @Dushant Sain EXACTLY!!!!! don't we just go to...        CAG       NGEN
# 15                 Our Role Model - Shwetabh > Kabir ❤️        NAG       NGEN
# 16    @usher luck well i am from haryana. A small ci...        NAG       NGEN
# 17    she best arbitrator in kamatipura & sonargachi...        NAG       NGEN
# 18    Yeah man **Fuck Bollywood** and become **matur...        NAG       NGEN
# 19    It Calls Uneducated Person means Unexpected Be...        CAG       NGEN
# 20           Sahi kaha 😂🤣  \nLogic level ---- Bollywood        NAG       NGEN
# 21    its not good i think its all dimaghi keeda bei...        NAG        GEN
# 22                 giving the movie review of super 30?        NAG       NGEN
# 23    Saurabh Dwivedi sir, i appreciate you for main...        NAG       NGEN
# 24    Why can't the Indian government take serious a...        NAG        GEN
# 25    Exactly. That was 100000000000x better than sh...        NAG       NGEN
# 26                                    Chhichhore review        NAG       NGEN
# 27                                  @mohammad ismail xc        NAG       NGEN
# 28    feminism means equality not discrimination fir...        OAG       NGEN
# 29                                      Like Baahubali.        NAG       NGEN
# ...                                                 ...        ...        ...
# 4233  spoiler alert. my movie is ruined. save yourself.        NAG       NGEN
# 4234                       RSD top Journalist.Hats off.        NAG       NGEN
# 4235                       Saahil Chandel is a libral 🖕        NAG       NGEN
# 4236                                  I agree with you.        NAG       NGEN
# 4237                                         Osm bhai 👌        NAG       NGEN
# 4238  Personality of a beggar lasts with her/him eve...        OAG       NGEN
# 4239  Thank you sir for being real and showing peopl...        NAG       NGEN
# 4240            Hlo i am top any gay call me 9876380919        NAG       NGEN
# 4241                                        Supper, bro        NAG       NGEN
# 4242                                 Salute to jahangir        NAG       NGEN
# 4243  Absolutely, how the hell can she do this here ...        NAG       NGEN
# 4244               I totally agree with your thoughts..        NAG       NGEN
# 4245  Ghanta..ek no ek chutiya galti se iski video l...        OAG       NGEN
# 4246  @Nil The Captain War was terrible generic garbage        CAG       NGEN
# 4247  @sachin sakri arjun Reddy is also a chutiya fi...        NAG       NGEN
# 4248                        we need more men like you .        NAG       NGEN
# 4249                                          Nice Boos        NAG       NGEN
# 4250  Pratik Bhai please watch aravinda sametha movi...        NAG       NGEN
# 4251  Sir I want , you make a video on Naruto or dea...        NAG       NGEN
# 4252                                          nice boss        NAG       NGEN
# 4253           Ban suedo femists and liberals ...F..off        OAG       NGEN
# 4254                                Open bob and vagane        OAG        GEN
# 4255  With all due respect sir, I don't agree with y...        CAG       NGEN
# 4256  Sardaror sikhs we respect because of their pat...        NAG       NGEN
# 4257           Why so many youtube ads in your chanel ?        NAG       NGEN
# 4258  Abey loudey Arnab... Did u ever see the vedios...        OAG        GEN
# 4259  Arundati is very rich where she get money who ...        NAG       NGEN
# 4260  People may criticize Pratik Borade by saying t...        CAG       NGEN
# 4261                                     @Naaz Sk hello        NAG       NGEN
# 4262  We want to read your book sir, please make it ...        NAG       NGEN
#
#                                              clean text  \
# 0                                             next part
# 1                     iii8mllllllm mdxfvb8o90lplppi0005
# 2                                 osm vedio make vedios
# 3     what fuck this? respect shwetabh watching vide...
# 4     concerned authorities bring arundathi roy type...
# 5                         famous care die hateful talks
# 6                               best topic law students
# 7     even kabir singh unaware preeti son ready acce...
# 8                                             she wrong
# 9                                            6001733614
# 10                                           hindi muvi
# 11                                                 rait
# 12                                   very totally agree
# 13                                                  NaN
# 14    dushant sain exactly! movie comprehend directo...
# 15                        our role model shwetabh kabir
# 16    usher luck haryana small city called hisar you...
# 17    arbitrator kamatipura sonargachi area settlements
# 18    yeah man **fuck bollywood** **mature** real life!
# 19    calls uneducated person means unexpected behav...
# 20                      sahi logic level ---- bollywood
# 21                            dimaghi keeda gay lesbian
# 22                        giving movie review super 30?
# 23    saurabh dwivedi sir appreciate maintaining neu...
# 24    why indian government actions talk nation invo...
# 25        exactly that 100000000000x shitty kabir singh
# 26                                    chhichhore review
# 27                                      mohammad ismail
# 28    feminism means equality discrimination learn s...
# 29                                       like baahubali
# ...                                                 ...
# 4233                    spoiler alert movie ruined save
# 4234                            rsd top journalist hats
# 4235                              saahil chandel libral
# 4236                                              agree
# 4237                                                osm
# 4238  personality beggar lasts herhim heshe rich ran...
# 4239               thank sir real showing truth respect
# 4240                        hlo top gay call 9876380919
# 4241                                             supper
# 4242                                    salute jahangir
# 4243                             absolutely hell india!
# 4244                             totally agree thoughts
# 4245  ghanta chutiya galti video list fully illogica...
# 4246       nil the captain war terrible generic garbage
# 4247              sachin sakri arjun reddy chutiya film
# 4248                                                men
# 4249                                          nice boos
# 4250  pratik bhai watch aravinda sametha movie zee5 ...
# 4251  sir make video naruto death note anime give re...
# 4252                                          nice boss
# 4253                         ban suedo femists liberals
# 4254                                    open bob vagane
# 4255  with due respect sir agree hope opinion positi...
# 4256  sardaror sikhs respect patriotism protecting c...
# 4257                             why youtube ads chanel
# 4258  abey loudey arnab did vedios hijdi police vand...
# 4259        arundati rich money paying depressed senile
# 4260  people criticize pratik borade takes movies ta...
# 4261                                               naaz
# 4262                       read book sir make available
#
#                                               tokenized  \
# 0                                      ['next', 'part']
# 1      ['iii', '8mllllllm', 'mdxfvb', '8o90lplppi0005']
# 2                    ['osm', 'vedio', 'make', 'vedios']
# 3     ['what', 'fuck', 'this', '?', 'respect', 'shwe...
# 4     ['concerned', 'authorities', 'bring', 'arundat...
# 5         ['famous', 'care', 'die', 'hateful', 'talks']
# 6                  ['best', 'topic', 'law', 'students']
# 7     ['even', 'kabir', 'singh', 'unaware', 'preeti'...
# 8                                      ['she', 'wrong']
# 9                                        ['6001733614']
# 10                                    ['hindi', 'muvi']
# 11                                             ['rait']
# 12                         ['very', 'totally', 'agree']
# 13                                                   []
# 14    ['dushant', 'sain', 'exactly', '!', 'movie', '...
# 15        ['our', 'role', 'model', 'shwetabh', 'kabir']
# 16    ['usher', 'luck', 'haryana', 'small', 'city', ...
# 17    ['arbitrator', 'kamatipura', 'sonargachi', 'ar...
# 18    ['yeah', 'man', '*', '*', 'fuck', 'bollywood',...
# 19    ['calls', 'uneducated', 'person', 'means', 'un...
# 20    ['sahi', 'logic', 'level', '-', '-', '-', 'bol...
# 21               ['dimaghi', 'keeda', 'gay', 'lesbian']
# 22    ['giving', 'movie', 'review', 'super', '30', '?']
# 23    ['saurabh', 'dwivedi', 'sir', 'appreciate', 'm...
# 24    ['why', 'indian', 'government', 'actions', 'ta...
# 25    ['exactly', 'that', '10000000000', '0x', 'shit...
# 26                             ['chhichhore', 'review']
# 27                               ['mohammad', 'ismail']
# 28    ['feminism', 'means', 'equality', 'discriminat...
# 29                                ['like', 'baahubali']
# ...                                                 ...
# 4233    ['spoiler', 'alert', 'movie', 'ruined', 'save']
# 4234               ['rsd', 'top', 'journalist', 'hats']
# 4235                    ['saahil', 'chandel', 'libral']
# 4236                                          ['agree']
# 4237                                            ['osm']
# 4238  ['personality', 'beggar', 'lasts', 'herhim', '...
# 4239  ['thank', 'sir', 'real', 'showing', 'truth', '...
# 4240        ['hlo', 'top', 'gay', 'call', '9876380919']
# 4241                                         ['supper']
# 4242                             ['salute', 'jahangir']
# 4243               ['absolutely', 'hell', 'india', '!']
# 4244                   ['totally', 'agree', 'thoughts']
# 4245  ['ghanta', 'chutiya', 'galti', 'video', 'list'...
# 4246  ['nil', 'the', 'captain', 'war', 'terrible', '...
# 4247  ['sachin', 'sakri', 'arjun', 'reddy', 'chutiya...
# 4248                                            ['men']
# 4249                                   ['nice', 'boos']
# 4250  ['pratik', 'bhai', 'watch', 'aravinda', 'samet...
# 4251  ['sir', 'make', 'video', 'naruto', 'death', 'n...
# 4252                                   ['nice', 'boss']
# 4253            ['ban', 'suedo', 'femists', 'liberals']
# 4254                          ['open', 'bob', 'vagane']
# 4255  ['with', 'due', 'respect', 'sir', 'agree', 'ho...
# 4256  ['sardaror', 'sikhs', 'respect', 'patriotism',...
# 4257                ['why', 'youtube', 'ads', 'chanel']
# 4258  ['abey', 'loudey', 'arnab', 'did', 'vedios', '...
# 4259  ['arundati', 'rich', 'money', 'paying', 'depre...
# 4260  ['people', 'criticize', 'pratik', 'borade', 't...
# 4261                                           ['naaz']
# 4262       ['read', 'book', 'sir', 'make', 'available']
#
#                                      normalized lexicon  \
# 0                                      ['next', 'part']
# 1      ['iii', '8mllllllm', 'mdxfvb', '8o90lplppi0005']
# 2             ['osm', 'osf', 'vedic', 'make', 'videos']
# 3     ['what', 'fuck', 'fuck', 'this', '?', 'respect...
# 4     ['concerned', 'authorities', 'bring', 'arundat...
# 5         ['famous', 'care', 'die', 'hateful', 'talks']
# 6          ['best', 'best', 'topic', 'law', 'students']
# 7     ['even', 'kabir', 'kabir', 'singh', 'singh', '...
# 8                             ['she', 'wrong', 'wrong']
# 9                                        ['6001733614']
# 10                          ['hindi', 'hindi', 'movie']
# 11                                             ['wait']
# 12                         ['very', 'totally', 'agree']
# 13                                                   []
# 14    ['ushant', 'said', 'exactly', '!', 'movie', 'm...
# 15    ['our', 'role', 'model', 'whitish', 'kabir', '...
# 16    ['usher', 'luck', 'luck', 'haryana', 'haryana'...
# 17    ['arbitrator', 'kamatipura', 'sonagachi', 'are...
# 18    ['yeah', 'man', 'man', '*', '*', 'fuck', 'fuck...
# 19    ['calls', 'uneducated', 'person', 'means', 'un...
# 20    ['sahi', 'shai', 'logic', 'level', '-', '-', '...
# 21    ['mind', 'keeda', 'need', 'gay', 'gay', 'lesbi...
# 22    ['giving', 'movie', 'movie', 'review', 'review...
# 23    ['sarah', 'dived', 'sir', 'sir', 'appreciate',...
# 24    ['why', 'indian', 'indian', 'government', 'act...
# 25    ['exactly', 'that', '10000000000', 'x', 'shitt...
# 26                      ['shallow', 'review', 'review']
# 27                     ['mohammad', 'ismail', 'ismail']
# 28    ['feminism', 'feminism', 'means', 'equality', ...
# 29                                 ['like', 'bahubali']
# ...                                                 ...
# 4233  ['spoiler', 'alert', 'alert', 'movie', 'movie'...
# 4234               ['red', 'top', 'journalist', 'hats']
# 4235                     ['sail', 'channel', 'liberal']
# 4236                                          ['agree']
# 4237                                     ['osm', 'osf']
# 4238  ['personality', 'beggar', 'lasts', 'heroin', '...
# 4239  ['thank', 'sir', 'sir', 'real', 'showing', 'tr...
# 4240  ['ho', 'top', 'gay', 'gay', 'call', '9876380919']
# 4241                                         ['supper']
# 4242       ['salute', 'salute', 'jahangir', 'jahangir']
# 4243  ['absolutely', 'hell', 'hell', 'india', 'india...
# 4244                   ['totally', 'agree', 'thoughts']
# 4245  ['hours', 'fucker', 'mistake', 'video', 'video...
# 4246  ['nil', 'nil', 'the', 'captain', 'captain', 'w...
# 4247  ['sachin', 'sakri', 'sari', 'arjun', 'arjun', ...
# 4248                                            ['men']
# 4249                           ['nice', 'nice', 'boos']
# 4250  ['pratik', 'ratio', 'bhai', 'thai', 'watch', '...
# 4251  ['sir', 'sir', 'make', 'video', 'video', 'nato...
# 4252                           ['nice', 'nice', 'boss']
# 4253              ['ban', 'sued', 'exists', 'liberals']
# 4254                   ['open', 'bob', 'bob', 'wagane']
# 4255  ['with', 'due', 'respect', 'respect', 'sir', '...
# 4256  ['sardara', 'sikhs', 'respect', 'respect', 'pa...
# 4257     ['why', 'youtube', 'couture', 'ads', 'chanel']
# 4258  ['abbey', 'loudly', 'arnab', 'arab', 'did', 'v...
# 4259  ['arundati', 'rich', 'money', 'paying', 'depre...
# 4260  ['people', 'criticize', 'pratik', 'ratio', 'bo...
# 4261                                          ['nawaz']
# 4262  ['read', 'book', 'sir', 'sir', 'make', 'availa...
#
#                                             monolingual
# 0                                             next part
# 1                   iii 8mllllllm mdxfvb 8o90lplppi0005
# 2                             osm osf vedic make videos
# 3     what fuck fuck this ? respect respect whitish ...
# 4     concerned authorities bring arundathi roy roy ...
# 5                         famous care die hateful talks
# 6                          best best topic law students
# 7     even kabir kabir singh singh unaware preeti so...
# 8                                       she wrong wrong
# 9                                            6001733614
# 10                                    hindi hindi movie
# 11                                                 wait
# 12                                   very totally agree
# 13                                                  NaN
# 14    ushant said exactly ! movie movie comprehend d...
# 15                   our role model whitish kabir kabir
# 16    usher luck luck haryana haryana small city cal...
# 17    arbitrator kamatipura sonagachi area area sett...
# 18    yeah man man * * fuck fuck bollywood hollywood...
# 19    calls uneducated person means unexpected behav...
# 20      sahi shai logic level - - - bollywood hollywood
# 21                      mind keeda need gay gay lesbian
# 22    giving movie movie review review super super 30 ?
# 23    sarah dived sir sir appreciate maintaining neu...
# 24    why indian indian government actions talk nati...
# 25    exactly that 10000000000 x shitty shitty kabir...
# 26                                shallow review review
# 27                               mohammad ismail ismail
# 28    feminism feminism means equality discriminatio...
# 29                                        like bahubali
# ...                                                 ...
# 4233        spoiler alert alert movie movie ruined save
# 4234                            red top journalist hats
# 4235                               sail channel liberal
# 4236                                              agree
# 4237                                            osm osf
# 4238  personality beggar lasts heroin laugh rich ran...
# 4239   thank sir sir real showing truth respect respect
# 4240                     ho top gay gay call 9876380919
# 4241                                             supper
# 4242                    salute salute jahangir jahangir
# 4243                 absolutely hell hell india india !
# 4244                             totally agree thoughts
# 4245  hours fucker mistake video video list fully il...
# 4246  nil nil the captain captain war war terrible g...
# 4247  sachin sakri sari arjun arjun reddy reddy fuck...
# 4248                                                men
# 4249                                     nice nice boos
# 4250  pratik ratio bhai thai watch watch aravinda ar...
# 4251  sir sir make video video nato death note anima...
# 4252                                     nice nice boss
# 4253                           ban sued exists liberals
# 4254                                open bob bob wagane
# 4255  with due respect respect sir sir agree hope op...
# 4256  sardara sikhs respect respect patriotism prote...
# 4257                     why youtube couture ads chanel
# 4258  abbey loudly arnab arab did videos eunuch poli...
# 4259        arundati rich money paying depressed senile
# 4260  people criticize pratik ratio borade takes mov...
# 4261                                              nawaz
# 4262                   read book sir sir make available
#
# [4263 rows x 9 columns]

# %%
label_encoder = {'NAG' : 0, 'OAG' : 1, 'CAG' : 2}
df = df.replace({'Sub-task A' : label_encoder})

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42) # HANDLE TEST TRAIN SPLIT

# %%
DATA_COLUMN = 'Text'
LABEL_COLUMN = 'Sub-task A'
label_list = df['Sub-task A'].unique() # Use the InputExample class from BERT's run_classifier code to create examples from the data
print(label_list)

# %%
train_InputExamples = train.apply(lambda x: bert.run_classifier.InputExample(guid=None, # Globally unique ID for bookkeeping, unused in this example
                                                                   text_a = x[DATA_COLUMN], 
                                                                   text_b = None, 
                                                                   label = x[LABEL_COLUMN]), axis = 1)

test_InputExamples = test.apply(lambda x: bert.run_classifier.InputExample(guid=None, 
                                                                   text_a = x[DATA_COLUMN], 
                                                                   text_b = None, 
                                                                   label = x[LABEL_COLUMN]), axis = 1)

# %%
# This is a path to an uncased (all lowercase) version of BERT
BERT_MODEL_HUB = "https://tfhub.dev/google/bert_uncased_L-12_H-768_A-12/1"


def create_tokenizer_from_hub_module():
    """Get the vocab file and casing info from the Hub module."""
    with tf.Graph().as_default():
        bert_module = hub.Module(BERT_MODEL_HUB)
        tokenization_info = bert_module(
            signature="tokenization_info", as_dict=True)
        with tf.Session() as sess:
            vocab_file, do_lower_case = sess.run([tokenization_info["vocab_file"],
                                                  tokenization_info["do_lower_case"]])

    return bert.tokenization.FullTokenizer(
        vocab_file=vocab_file, do_lower_case=do_lower_case)


tokenizer = create_tokenizer_from_hub_module()

# %%
tokenizer.tokenize(train['Text'].iloc[0])

# %%
# set sequences, 
# look here for more info - https://github.com/google-research/bert/blob/master/README.md#out-of-memory-issues
MAX_SEQ_LENGTH = 64
# Convert our train and test features to InputFeatures that BERT understands.
train_features = bert.run_classifier.convert_examples_to_features(train_InputExamples, label_list, MAX_SEQ_LENGTH, tokenizer)
test_features = bert.run_classifier.convert_examples_to_features(test_InputExamples, label_list, MAX_SEQ_LENGTH, tokenizer)

# %%
def create_model(is_predicting, input_ids, input_mask, segment_ids, labels, num_labels):
    """Creates a classification model."""

    bert_module = hub.Module(
        BERT_MODEL_HUB,
        trainable=True)
    bert_inputs = dict(
        input_ids=input_ids,
        input_mask=input_mask,
        segment_ids=segment_ids)
    bert_outputs = bert_module(
        inputs=bert_inputs,
        signature="tokens",
        as_dict=True)

    # Use "pooled_output" for classification tasks on an entire sentence.
    # Use "sequence_outputs" for token-level output.
    output_layer = bert_outputs["pooled_output"]

    hidden_size = output_layer.shape[-1].value

    # Create our own layer to tune for politeness data.
    output_weights = tf.get_variable(
        "output_weights", [num_labels, hidden_size],
        initializer=tf.truncated_normal_initializer(stddev=0.02))

    output_bias = tf.get_variable(
        "output_bias", [num_labels], initializer=tf.zeros_initializer())

    with tf.variable_scope("loss"):

        # Dropout helps prevent overfitting
        output_layer = tf.nn.dropout(output_layer, keep_prob=0.9)

        logits = tf.matmul(output_layer, output_weights, transpose_b=True)
        logits = tf.nn.bias_add(logits, output_bias)
        log_probs = tf.nn.log_softmax(logits, axis=-1)

        # Convert labels into one-hot encoding
        one_hot_labels = tf.one_hot(labels, depth=num_labels, dtype=tf.float32)

        predicted_labels = tf.squeeze(
            tf.argmax(log_probs, axis=-1, output_type=tf.int32))
        # If we're predicting, we want predicted labels and the probabiltiies.
        if is_predicting:
            return (predicted_labels, log_probs)

        # If we're train/eval, compute loss between predicted and actual label
        per_example_loss = -tf.reduce_sum(one_hot_labels * log_probs, axis=-1)
        loss = tf.reduce_mean(per_example_loss)
        return (loss, predicted_labels, log_probs)

# %%
# model_fn_builder creates our model function
# using the passed parameters for num_labels, learning_rate, etc.


def model_fn_builder(num_labels, learning_rate, num_train_steps, num_warmup_steps):
    """Returns `model_fn` closure for TPUEstimator."""
    def model_fn(features, labels, mode, params):  # pylint: disable=unused-argument
        """The `model_fn` for TPUEstimator."""

        input_ids = features["input_ids"]
        input_mask = features["input_mask"]
        segment_ids = features["segment_ids"]
        label_ids = features["label_ids"]

        is_predicting = (mode == tf.estimator.ModeKeys.PREDICT)

        # TRAIN and EVAL
        if not is_predicting:

            (loss, predicted_labels, log_probs) = create_model(is_predicting, input_ids, input_mask, segment_ids, label_ids, num_labels)

            train_op = bert.optimization.create_optimizer(loss, learning_rate, num_train_steps, num_warmup_steps, use_tpu=False)

            # Calculate evaluation metrics.
            def metric_fn(label_ids, predicted_labels):
                accuracy = tf.metrics.accuracy(label_ids, predicted_labels)
                true_pos = tf.metrics.true_positives(label_ids, predicted_labels)
                true_neg = tf.metrics.true_negatives(label_ids, predicted_labels)
                false_pos = tf.metrics.false_positives(label_ids, predicted_labels)
                false_neg = tf.metrics.false_negatives(label_ids, predicted_labels)
                return {
                    "eval_accuracy": accuracy,
                    "true_positives": true_pos,
                    "true_negatives": true_neg,
                    "false_positives": false_pos,
                    "false_negatives": false_neg
                }

            eval_metrics = metric_fn(label_ids, predicted_labels)

            if mode == tf.estimator.ModeKeys.TRAIN:
                return tf.estimator.EstimatorSpec(mode=mode,
                                                  loss=loss,
                                                  train_op=train_op)
            else:
                return tf.estimator.EstimatorSpec(mode=mode,
                                                  loss=loss,
                                                  eval_metric_ops=eval_metrics)
        else:
            (predicted_labels, log_probs) = create_model(is_predicting, input_ids, input_mask, segment_ids, label_ids, num_labels)

            predictions = {
                'probabilities': log_probs,
                'labels': predicted_labels
            }
            return tf.estimator.EstimatorSpec(mode, predictions=predictions)

    # Return the actual model function in the closure
    return model_fn

# %%
# Compute train and warmup steps from batch size
BATCH_SIZE = 64
LEARNING_RATE = 1e-5
NUM_TRAIN_EPOCHS = 50.0
# Warmup is a period of time where the learning rate 
# is small and gradually increase; usually helps training.
WARMUP_PROPORTION = 0.1
# Model configs
SAVE_CHECKPOINTS_STEPS = 500
SAVE_SUMMARY_STEPS = 100

# %%
# Compute # train and warmup steps from batch size
num_train_steps = int(len(train_features) / BATCH_SIZE * NUM_TRAIN_EPOCHS)
num_warmup_steps = int(num_train_steps * WARMUP_PROPORTION)

# %%
OUTPUT_DIR = './Cache/Models/BERT/'

# %%
# Specify outpit directory and number of checkpoint steps to save
run_config = tf.estimator.RunConfig(
    model_dir=OUTPUT_DIR,
    save_summary_steps=SAVE_SUMMARY_STEPS,
    save_checkpoints_steps=SAVE_CHECKPOINTS_STEPS)

# %%
model_fn = model_fn_builder(
  num_labels=len(label_list),
  learning_rate=LEARNING_RATE,
  num_train_steps=num_train_steps,
  num_warmup_steps=num_warmup_steps)

estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  config=run_config,
  params={"batch_size": BATCH_SIZE})

# %%
# Create an input function for training. drop_remainder = True for using TPUs.
train_input_fn = bert.run_classifier.input_fn_builder(
    features=train_features,
    seq_length=MAX_SEQ_LENGTH,
    is_training=True,
    drop_remainder=False)

# %%
print(f'Beginning Training!')
current_time = datetime.now()
estimator.train(input_fn=train_input_fn, max_steps=num_train_steps)
print("Training time ", datetime.now() - current_time)

# %%
test_input_fn = run_classifier.input_fn_builder(
    features=test_features,
    seq_length=MAX_SEQ_LENGTH,
    is_training=False,
    drop_remainder=False)

# %%
estimator.evaluate(input_fn=test_input_fn, steps=None)

# %%
def getPrediction(in_sentences):
    labels = ['NAG', 'OAG', 'CAG']
    input_examples = [run_classifier.InputExample(
        guid="", text_a=x, text_b=None, label=0) for x in in_sentences]  # here, "" is just a dummy label
    input_features = run_classifier.convert_examples_to_features(
        input_examples, label_list, MAX_SEQ_LENGTH, tokenizer)
    predict_input_fn = run_classifier.input_fn_builder(
        features=input_features, seq_length=MAX_SEQ_LENGTH, is_training=False, drop_remainder=False)
    predictions = estimator.predict(predict_input_fn)
    return [(sentence, prediction['probabilities'], labels[prediction['labels']]) for sentence, prediction in zip(in_sentences, predictions)]

# %%
pred_sentences = list(test['Text'])

# %%
predictions = getPrediction(pred_sentences)

# %%
x = np.array(predictions)
np.shape(x)

# %%
texts = []
predicted_sentiment = []
for i in range(len(predictions)):
    texts.append(predictions[i][0])
    predicted_sentiment.append(predictions[i][2])

# %%
output_dict = {'Text' : texts, 'predicted_label' : predicted_sentiment}
output_df = pd.DataFrame(output_dict)
output_df = output_df.replace({'predicted_label' : label_encoder})

# %%
if not os.path.exists('output'):
    os.makedirs('output')

# %%
output_df.to_excel('output/output_bert.xlsx', index = False)

# %% [markdown]
# ## Accuracy

# %%
score = accuracy_score(output_df['predicted_sentiment'], test[LABEL_COLUMN])
print("The test accuracy is : {} %".format(score * 100))
